# %% [markdown]
# # Import Pandas Library
# - Read the Titanic dataset into a DataFrame

# %%
import pandas as pd
df = pd.read_csv('titanic_dataset_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 1. How Big is the Dataset?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How the Data Looks Like?

# %%
df.head()   # Display first 5 rows
df.tail()   # Display last 5 rows
df.sample(5) # Display 5 random rows
# Out:
#      PassengerId  Survived  Pclass  \
# 561          562         0       3
# 18            19         0       3
# 340          341         1       2
# 831          832         1       2
# 357          358         0       2
#
#                                                   Name     Sex    Age  SibSp  \
# 561                                  Sivic, Mr. Husein    male  40.00      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.00      1
# 340                     Navratil, Master. Edmond Roger    male   2.00      1
# 831                    Richards, Master. George Sibley    male   0.83      1
# 357                          Funk, Miss. Annie Clemmer  female  38.00      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 561      0  349251   7.8958   NaN        S
# 18       0  345763  18.0000   NaN        S
# 340      1  230080  26.0000    F2        S
# 831      1   29106  18.7500   NaN        S
# 357      0  237671  13.0000   NaN        S

# %% [markdown]
# # 3. What is the Data Types of Each Feature?
# - (feature is a column in the dataset)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there Missing Values in the Dataset?

# %%
df.isnull() # Displays True/False for missing values. 
df.isnull().sum() # Sum of missing values per column.
#df.isnull().mean() # Proportion of missing values per column.
#df.isnull().mean().sort_values(ascending=False) # Sorted proportion of missing values per column.
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. Summary Statistics of *Numerical Features* or Descriptive Statistics or How does the data look mathmatically?

# %%
df.describe() # only for numerical features (int and float)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Summary Statistics of *Categorical Features*

# %%
df.describe(include=['O']) # only for categorical features (object)
# top - most frequent value
# freq - frequency of the most frequent value
# unique - number of unique values
# count - number of non-missing values



#df.describe(include='all') # for all features 
#df['Age'].describe() # describe for a specific column
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %% [markdown]
# # 7. Are there Duplicated Rows in the Dataset?
# Duplicated_Rows = df.duplicated()
# print("Number of Duplicated Rows: ", Duplicated_Rows.sum())

# %%
df.duplicated() # Returns a boolean Series denoting duplicate rows.
df.duplicated().sum() # Number of duplicated rows
# Out:
# 0

# %% [markdown]
# # 8. Coorelation between Numerical Features

# %% [markdown]
# - What is correlation?
# Coorelation is a statistical measure that describes the extent to which two variables change together. It indicates the strength and direction of a linear relationship between two numerical features. The correlation coefficient ranges from -1 to +1, where:
#   - +1 indicates a perfect positive correlation (as one variable increases, the other also increases).
#   - -1 indicates a perfect negative correlation (as one variable increases, the other decreases).
#
# - What is method parameter in df.corr() function?
# The method parameter in the df.corr() function specifies the method to be used for calculating the correlation between numerical features. The available methods are:
#   - 'pearson': This is the default method and calculates the Pearson correlation coefficient, which measures the linear relationship between two continuous variables.
#   - 'spearman': This method calculates the Spearman rank correlation coefficient, which assesses how well the relationship between two variables can be described using a monotonic function. It is suitable for ordinal data or non-linear relationships.
#   - 'kendall': This method calculates the Kendall tau correlation coefficient, which measures the ordinal association between two variables. It is also suitable for ordinal data and is less sensitive to outliers compared to Pearson correlation.
#
# - What is numeric_only parameter in df.corr() function?
# The numeric_only parameter tells pandas whether to use only numeric columns when calculating correlation.
# `numeric_only=True` → use only numbers (ignore text, dates, etc.)
# `numeric_only=False` → try to include all columns (may cause errors if non-numeric data exists)
# It helps avoid errors when your DataFrame has non-numeric data.

# %% [markdown]
# **color-coded correlation table (heatmap style)**
#
# `.style.background_gradient(...)` → .style is an accessor whcih adds colors to the table, background_gradient() is a method which it styles the output.
#
# `cmap='coolwarm'` → it’s a parameter that specifies the color map to use for the gradient. 'coolwarm' is a popular choice that uses a gradient from cool colors (blue) to warm colors (red).
#
# - Red = strong positive correlation
#
# - Blue = strong negative correlation
#
# - White/light = weak or no correlation
#
# Together, it shows a color-coded correlation table (heatmap style) that makes relationships easy to see at a glance.

# %%
df.corr(numeric_only=True) # Correlation between numerical features
df.corr(method='pearson', numeric_only=True) # Pearson correlation (default)
df.corr(method='spearman', numeric_only=True) # Spearman correlation
df.corr(method='kendall', numeric_only=True) # Kendall correlation

df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm') # Heatmap style correlation matrix
# Out:
# <style type="text/css">
# #T_604dc_row0_col0, #T_604dc_row1_col1, #T_604dc_row2_col2, #T_604dc_row3_col3, #T_604dc_row4_col4, #T_604dc_row5_col5, #T_604dc_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_604dc_row0_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_604dc_row0_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_604dc_row0_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_604dc_row0_col4, #T_604dc_row3_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_604dc_row0_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_604dc_row0_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_604dc_row1_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_604dc_row1_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_604dc_row1_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_604dc_row1_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_604dc_row1_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_604dc_row1_col6 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_604dc_row2_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_604dc_row2_col1, #T_604dc_row2_col3, #T_604dc_row2_col6, #T_604dc_row3_col4, #T_604dc_row3_col5, #T_604dc_row4_col0, #T_604dc_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_604dc_row2_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_604dc_row2_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_604dc_row3_col0 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_604dc_row3_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_604dc_row3_col6 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_604dc_row4_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_604dc_row4_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_604dc_row4_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_604dc_row4_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_604dc_row4_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_604dc_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_604dc_row5_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_604dc_row5_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_604dc_row5_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_604dc_row5_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_604dc_row5_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_604dc_row6_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_604dc_row6_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_604dc_row6_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_604dc_row6_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_604dc_row6_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# </style>
# <table id="T_604dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_604dc_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_604dc_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_604dc_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_604dc_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_604dc_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_604dc_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_604dc_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_604dc_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_604dc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_604dc_row0_col1" class="data row0 col1" >-0.005007</td>
#       <td id="T_604dc_row0_col2" class="data row0 col2" >-0.035144</td>
#       <td id="T_604dc_row0_col3" class="data row0 col3" >0.036847</td>
#       <td id="T_604dc_row0_col4" class="data row0 col4" >-0.057527</td>
#       <td id="T_604dc_row0_col5" class="data row0 col5" >-0.001652</td>
#       <td id="T_604dc_row0_col6" class="data row0 col6" >0.012658</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_604dc_row1_col0" class="data row1 col0" >-0.005007</td>
#       <td id="T_604dc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_604dc_row1_col2" class="data row1 col2" >-0.338481</td>
#       <td id="T_604dc_row1_col3" class="data row1 col3" >-0.077221</td>
#       <td id="T_604dc_row1_col4" class="data row1 col4" >-0.035322</td>
#       <td id="T_604dc_row1_col5" class="data row1 col5" >0.081629</td>
#       <td id="T_604dc_row1_col6" class="data row1 col6" >0.257307</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_604dc_row2_col0" class="data row2 col0" >-0.035144</td>
#       <td id="T_604dc_row2_col1" class="data row2 col1" >-0.338481</td>
#       <td id="T_604dc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_604dc_row2_col3" class="data row2 col3" >-0.369226</td>
#       <td id="T_604dc_row2_col4" class="data row2 col4" >0.083081</td>
#       <td id="T_604dc_row2_col5" class="data row2 col5" >0.018443</td>
#       <td id="T_604dc_row2_col6" class="data row2 col6" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_604dc_row3_col0" class="data row3 col0" >0.036847</td>
#       <td id="T_604dc_row3_col1" class="data row3 col1" >-0.077221</td>
#       <td id="T_604dc_row3_col2" class="data row3 col2" >-0.369226</td>
#       <td id="T_604dc_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_604dc_row3_col4" class="data row3 col4" >-0.308247</td>
#       <td id="T_604dc_row3_col5" class="data row3 col5" >-0.189119</td>
#       <td id="T_604dc_row3_col6" class="data row3 col6" >0.096067</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_604dc_row4_col0" class="data row4 col0" >-0.057527</td>
#       <td id="T_604dc_row4_col1" class="data row4 col1" >-0.035322</td>
#       <td id="T_604dc_row4_col2" class="data row4 col2" >0.083081</td>
#       <td id="T_604dc_row4_col3" class="data row4 col3" >-0.308247</td>
#       <td id="T_604dc_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_604dc_row4_col5" class="data row4 col5" >0.414838</td>
#       <td id="T_604dc_row4_col6" class="data row4 col6" >0.159651</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_604dc_row5_col0" class="data row5 col0" >-0.001652</td>
#       <td id="T_604dc_row5_col1" class="data row5 col1" >0.081629</td>
#       <td id="T_604dc_row5_col2" class="data row5 col2" >0.018443</td>
#       <td id="T_604dc_row5_col3" class="data row5 col3" >-0.189119</td>
#       <td id="T_604dc_row5_col4" class="data row5 col4" >0.414838</td>
#       <td id="T_604dc_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_604dc_row5_col6" class="data row5 col6" >0.216225</td>
#     </tr>
#     <tr>
#       <th id="T_604dc_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_604dc_row6_col0" class="data row6 col0" >0.012658</td>
#       <td id="T_604dc_row6_col1" class="data row6 col1" >0.257307</td>
#       <td id="T_604dc_row6_col2" class="data row6 col2" >-0.549500</td>
#       <td id="T_604dc_row6_col3" class="data row6 col3" >0.096067</td>
#       <td id="T_604dc_row6_col4" class="data row6 col4" >0.159651</td>
#       <td id="T_604dc_row6_col5" class="data row6 col5" >0.216225</td>
#       <td id="T_604dc_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
